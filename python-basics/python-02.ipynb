# %%
# ライブラリのインポート
# csv: CSVファイルを扱うためのライブラリ
# drive: Googleドライブを操作するためのライブラリ
import csv
from google.colab import drive


# 二次元配列を作成する
data = [
  ["id", "value"],
  ["1", "ABC"],
  ["2", "DEF"],
  ["3", "GHI"]
]

# 二次元配列をprintで出力
print(data)


# -----------------------------------------------------------------
# Google Colabのディレクトリに保存する
# -----------------------------------------------------------------
# csv_file_path = '/content/output.csv'

# # CSVファイルを指定された場所＆名前で保存
# with open(csv_file_path, mode='w', newline='') as file:
#   writer = csv.writer(file)
#   writer.writerows(data)


# -----------------------------------------------------------------
# Google ドライブに保存する
# -----------------------------------------------------------------

# # ドライブのマウントとファイルの場所を指定
# drive.mount('/content/drive')
# csv_file_path = '/content/drive/My Drive/tmp/output.csv'

# # CSVファイルを指定された場所＆名前で保存
# with open(csv_file_path, mode='w', newline='') as file:
#   writer = csv.writer(file)
#   writer.writerows(data)


# -----------------------------------------------------------------
# Google ドライブに保存したCSVファイルを読み込んで表示
# -----------------------------------------------------------------

# csv_file_path = '/content/drive/My Drive/tmp/output.csv'

# # CSVファイルを読み込んで二次元配列に格納
# input = []
# with open(csv_file_path, newline='', encoding='utf-8') as csvfile:
#   csvreader = csv.reader(csvfile)
#   for row in csvreader:
#     input.append(row)

# # 二次元配列を表示
# for row in input:
#   print(row)
